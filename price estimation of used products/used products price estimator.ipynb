# %%
from tkinter import *
from PIL import ImageTk ,Image

from tkinter import ttk


window = Tk()

window.title("USED PRODUCTS PRICE ESTIMATOR")
tab_control = ttk.Notebook(window)

tab1 = ttk.Frame(tab_control)

tab2 = ttk.Frame(tab_control)
tab3 = ttk.Frame(tab_control)

tab_control.add(tab1, text='  CARS  ')
tab_control.add(tab2, text='  MOBILES  ')
tab_control.add(tab3, text='  SOFAS  ')


def price():
    company = int(var1.get())
    kilometers = int(spin.get())
    maintainence = int(var3.get())
    performance = int(var4.get())
    calculation =  ((((company+maintainence +performance)*11000)-kilometers)*10)
    labelResult.config(text =calculation )
    
    
var1 = DoubleVar()
var3 = DoubleVar()
var4 = DoubleVar()





Tops = Frame(window, width = 1350, height = 50, bd = 8, relief = "raise")
Tops.pack(side = TOP)


f1d = Frame(tab1, width = 600, height = 100, bd = 8, relief = "raise")
f1d.pack(side=LEFT)
f1 = Frame(tab1, width = 500, height = 50, bd = 8, relief = "raise")
f1.pack(side = TOP)
f1a = Frame(f1d, width = 400, height = 50, bd = 8, relief = "raise")
f1a.pack(anchor=W)
f1b = Frame(f1d, width = 400, height = 50, bd = 8, relief = "raise")
f1b.pack(anchor=W)
f1c = Frame(f1d, width = 400, height = 50, bd = 8, relief = "raise")
f1c.pack(anchor=W)
f1e = Frame(f1, width = 400, height = 50, bd = 8, relief = "raise")
f1e.pack(anchor=W)
f1f = Frame(tab1, width = 400, height = 5, bd = 8, relief = "raise")
f1f.pack(side = BOTTOM)
f1g = Frame(f1, width = 400, height = 5, bd = 8, relief = "raise")
f1g.pack(anchor=W)




label1Title = Label(Tops, text = "          USED PRODUCTS PRICE ESTIMATOR         ", padx = 16, pady = 16, bd = 16, fg = '#000000', font = ("arial", 36, 'bold'), bg="blue",relief="raise",width=50,height=1)
label1Title.pack()




#tab1
lbl = Label(f1a, text="Choose your Car                                                              ", font=("Arial Bold", 20))
lbl.pack(anchor=W)
R2=Radiobutton(f1a,variable = var1,text="Hyundai Elantra 1.6 SX",font=(None,16),value=1)
R2.pack(anchor=W)
R3=Radiobutton(f1a,variable = var1,text="Jeep compass BSIV 1.4",font=(None,16),value=2)
R3.pack(anchor=W)
R4=Radiobutton(f1a,variable = var1,text="Toyota Innova crysta 2.4 GX AT",font=(None,16),value=3)
R4.pack(anchor=W)
R5=Radiobutton(f1a,variable = var1,text="Audi A3 35 TDI premium plus",font=(None,16),value=4)
R5.pack(anchor=W)
R1=Radiobutton(f1a,variable = var1,text="Volvo S60 D4 SUMMUM",font=(None,16),value=5)
R1.pack(anchor=W)


lbl = Label(f1b, text="Select no.of kilometer car has covered (approx)            ", font=("Arial Bold", 20))
lbl.pack(anchor=W)
spin = Spinbox(f1b, values=(1000,2000,3000,4000,5000,6000,7000,8000,9000,10000), width=20)
spin.pack(anchor=W)


lbl = Label(f1c, text="Car's exterior condition                                                   ", font=("Arial Bold", 20))
lbl.pack(anchor=N)
e1=Radiobutton(f1c,variable = var3,text="Excellent",font=(None,16),value=3)
e1.pack(anchor=W)
e2=Radiobutton(f1c,variable = var3,text="Minor scratches and colour faded ",font=(None,16),value=2)
e2.pack(anchor=W)
e3=Radiobutton(f1c,variable = var3,text="Worst",font=(None,16),value=1)
e3.pack(anchor=W)


labelw = Label(f1d, text = "engine performance rating", font =('arial', 20, 'bold'), bd = 20)
Bodyw = Scale(f1d, variable = var4, from_ = 1, to = 10, length = 500, tickinterval = 1, orient = HORIZONTAL)
labelw.pack()
Bodyw.pack(side=TOP)
labelResult = Label(f1e, padx = 16, pady = 16, bd = 16, fg = '#000000', font = ('arial', 30, 'bold'), bg = 'sky blue', relief = 'sunk', width = 34, height = 1)
labelResult.pack()



img=ImageTk.PhotoImage(Image.open ("C:\\Users\\Smile\\Desktop\\image1.jpg"))
lab=Label(f1f,image=img)
lab.pack()


btnBMI = Button(f1g, text = "Click to Check the PRICE", padx = 8, pady = 8,bg = "red", bd = 12, width = 45, font = ("arial", 20, 'bold'), height = 3,  command = price)
btnBMI.pack()



#tab2






f2d = Frame(tab2, width = 600, height = 100, bd = 8, relief = "raise")
f2d.pack(side=LEFT)
f2 = Frame(tab2, width = 500, height = 50, bd = 8, relief = "raise")
f2.pack(side = TOP)
f2a = Frame(f2d, width = 400, height = 50, bd = 8, relief = "raise")
f2a.pack(anchor=W)
f2b = Frame(f2d, width = 400, height = 50, bd = 8, relief = "raise")
f2b.pack(anchor=W)
f2c = Frame(f2d, width = 400, height = 50, bd = 8, relief = "raise")
f2c.pack(anchor=W)
f2e = Frame(f2, width = 400, height = 50, bd = 8, relief = "raise")
f2e.pack(anchor=W)
f2f = Frame(tab2, width = 400, height = 5, bd = 8, relief = "raise")
f2f.pack(side = BOTTOM)
f2g = Frame(f2, width = 400, height = 5, bd = 8, relief = "raise")
f2g.pack(anchor=W)

def mprice():
    defects = int(var5.get())
    invoice = int(chk_state .get())
    mobile = int(var6.get())
    missing = int(var8.get())
    cost =  (((mobile+invoice+15)-(defects+missing))*1000)
    labelResult1.config(text =cost )
    


var5 = DoubleVar()
var6 = DoubleVar()
var8 = DoubleVar()






lbl1 = Label(f2b, text="select the functional defects if any                                            ", font=("Arial Bold", 20))
lbl1.pack(anchor=W)
cheese=[('No defects', 1), ('broken screen', 6), ('speakers/mic not working', 2),
       ('charging/battery defect', 3), ('front cam no working', 5), ('any button not working', 4), ('bluetooth/GPS/wifi defect', 7)]
var5 = IntVar()
for text, value in cheese:
    Radiobutton(f2b, text=text, value=value, variable=var5,
                indicatoron=0).pack(anchor=W, fill=X, ipadx=18)

    
    
lbl2 = Label(f2a, text="Select the mobile below                                                             ", font=("Arial Bold", 20))
lbl2.pack(anchor=W) 
R13=Radiobutton(f2a,variable = var6,text="Oppo f15 blue 128gb",font=(None,16),value=1)
R13.pack(anchor=W)
R22=Radiobutton(f2a,variable = var6,text="Samsung galaxy s8 black 64gb",font=(None,16),value=3)
R22.pack(anchor=W)
R32=Radiobutton(f2a,variable = var6,text="Iphone 7 gold 32gb",font=(None,16),value=5)
R32.pack(anchor=W)
R42=Radiobutton(f2a,variable = var6,text="oneplus 7 256 gb",font=(None,16),value=8)
R42.pack(anchor=W)


lbl3 = Label(f2c, text="Invoice included in box                                                              ", font=("Arial Bold", 20))
lbl3.pack(anchor=W) 


chk_state = IntVar()

chk_state.set(0) #uncheck

chk_state.set(1) #check

chk = Checkbutton(f2c, text='Choose', var=chk_state)
chk.pack()


 
R23=Radiobutton(f2d,variable = var8,text="all acessories available with phone kit",font=(None,16),value=1)
R23.pack(anchor=W)
R33=Radiobutton(f2d,variable = var8,text="Earphones missing",font=(None,16),value=2)
R33.pack(anchor=W)
R43=Radiobutton(f2d,variable = var8,text="Charger missing",font=(None,16),value=3)
R43.pack(anchor=W)

labelResult1 = Label(f2e, padx = 16, pady = 16, bd = 16, fg = '#000000', font = ('arial', 30, 'bold'), bg = 'sky blue', relief = 'sunk', width = 34, height = 1)
labelResult1.pack()



img2=ImageTk.PhotoImage(Image.open ("C:\\Users\\Smile\\Desktop\\image2.png"))
laba=Label(f2f,image=img2)
laba.pack()

btnm = Button(f2g, text = "Click to Check the PRICE", padx = 8, pady = 8,bg = "red", bd = 12, width = 45, font = ("arial", 20, 'bold'), height = 3,command = mprice)
btnm.pack()


#tab3
f3d = Frame(tab3, width = 600, height = 100, bd = 8, relief = "raise")
f3d.pack(side=LEFT)
f3 = Frame(tab3, width = 500, height = 50, bd = 8, relief = "raise")
f3.pack(side = TOP)
f3h = Frame(f3d, width = 400, height = 50, bd = 8, relief = "raise")
f3h.pack(anchor=W)
f3a = Frame(f3d, width = 400, height = 50, bd = 8, relief = "raise")
f3a.pack(anchor=W)
f3b = Frame(f3d, width = 400, height = 50, bd = 8, relief = "raise")
f3b.pack(anchor=W)
f3c = Frame(f3d, width = 400, height = 50, bd = 8, relief = "raise")
f3c.pack(anchor=W)
f3e = Frame(f3, width = 400, height = 50, bd = 8, relief = "raise")
f3e.pack(anchor=W)
f3f = Frame(tab3, width = 400, height = 5, bd = 8, relief = "raise")
f3f.pack(side = BOTTOM)
f3g = Frame(f3, width = 400, height = 5, bd = 8, relief = "raise")
f3g.pack(anchor=W)


def sprice():
    types = int(var9.get())
    pillows = int(chk_state1 .get())
    seats= int(var10.get())
    condition = int(var11.get())
    sofacost =  (((types+pillows+condition)*seats)*1000)
    labelResult3.config(text =sofacost )
    


var9 = DoubleVar()
var10 = DoubleVar()
var11= DoubleVar()



lbl32 = Label(f3h, text="'The hardest distance is always from the sofa                               ",bg = "yellow", font=("Bold", 21))
lbl32.pack(anchor=W)
lbl52 = Label(f3h, text="to the front door'                                                                           ",bg = "yellow", font=("Bold", 21))
lbl52.pack(anchor=W)

lbl31 = Label(f3a, text="Select the type of sofa cushion filling                                       ", font=("Arial Bold", 20))
lbl31.pack(anchor=W) 
R55=Radiobutton(f3a,variable = var9,text="Foam",font=(None,16),value=5)
R55.pack(anchor=W)
R66=Radiobutton(f3a,variable = var9,text="Polyster",font=(None,16),value=3)
R66.pack(anchor=W)
R77=Radiobutton(f3a,variable = var9,text="Batting",font=(None,16),value=2)
R77.pack(anchor=W)


lbl33 = Label(f3b, text="select no of sofa seats                                                               ", font=("Arial Bold", 20))
lbl33.pack(anchor=W)
sofa=[('sofa with 1 seat', 1), ('sofa with 2 seats', 2), ('sofa with 3 seats', 3)]
var10 = IntVar()
for text, value in sofa:
    Radiobutton(f3b, text=text, value=value, variable=var10,
                indicatoron=0).pack(anchor=W, fill=X, ipadx=18)

    

lbl32 = Label(f3c, text="condition of sofa                                                                        ", font=("Arial Bold", 20))
lbl32.pack(anchor=W) 
R51=Radiobutton(f3c,variable = var11,text="good and well polished",font=(None,16),value=3)
R51.pack(anchor=W)
R61=Radiobutton(f3c,variable = var11,text="minor scratches/torn cushion",font=(None,16),value=2)
R61.pack(anchor=W)
R71=Radiobutton(f3c,variable = var11,text="minor defects in the body",font=(None,16),value=1)
R71.pack(anchor=W)

lb57 = Label(f3d, text="Pillows included with in the set                                                 ", font=("Arial Bold", 20))
lb57.pack(anchor=W) 


chk_state1 = IntVar()

chk_state1.set(0) #uncheck

chk_state1.set(1) #check

chk1 = Checkbutton(f3d, text='agree', var=chk_state1)
chk1.pack()

labelResult3 = Label(f3e, padx = 16, pady = 16, bd = 16, fg = '#000000', font = ('arial', 30, 'bold'), bg = 'pink', relief = 'sunk', width = 34, height = 1)
labelResult3.pack()

btns = Button(f3g, text = "Click to Check the PRICE", padx = 8, pady = 8,bg = "red", bd = 12, width = 45, font = ("arial", 20, 'bold'), height = 3,command =sprice )
btns.pack()

img3=ImageTk.PhotoImage(Image.open ("C:\\Users\\Smile\\Desktop\\image3.jpg"))
labb=Label(f3f,image=img3)
labb.pack()



tab_control.pack(expand=1, fill='both')

window.mainloop()

# %%
from tkinter import *
from PIL import ImageTk ,Image

base = Tk()
base.title('Start Button')

img=ImageTk.PhotoImage(Image.open ("C:\\Users\\Smile\\Desktop\\image1.jpg"))
lab=Label(image=img)
lab.pack()

button=Button(base,text='Click to Check the PRICE',command=base.quit)
button.pack()
base.mainloop()
